# %%
US

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 320000000
# S0 = 966000000
initS1 = 1
initE_0 = 60000
initE_V = 0
initI_0 = 16883
initI_V = 1
initR_0 = 19178
initR_V = 0
initR3 = 35371521
initR4 = 0
initD = 156

beta = 1.49998424
beta1 = 1.93045846
beta2 = 0.43544566
#alpha1=alpha1
k1 = 0.20000000
k2 = 0.30000176
deta1 = 0.05391035
deta2 = 0.01232153

gama1 = 0.08532973
gama2 = 0.25009874
alpha1=0.25046074
yita1=8.3946e-06
yita2=0.20402875
days =211

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
'''UK'''

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 67500000
# S0 = 966000000
initS1 = 1
initE_0 = 40000
initE_V = 0
initI_0 = 45140
initI_V = 1
initR_0 = 36704
initR_V = 0
initR3 = 6916439
initR4 = 0
initD = 57
beta = 1.49861808
beta1 = 3.24181830
beta2 = 0.44250901
#alpha1=alpha1


k1 = 0.25000000
k2 = 0.30000291
deta1 = 0.03759052
deta2 = 0.00206584

gama1 = 0.08738460
gama2 = 0.26313153
alpha1=0.23093328
yita1=3.8533e-12
yita2=0.20008634
days =211

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=3.2, max=7)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.18, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
france

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 67500000
# S0 = 966000000
initS1 = 1
initE_0 = 20000
initE_V = 0
initI_0 = 3778
initI_V = 1
initR_0 = 1294
initR_V = 0
initR3 = 6878368
initR4 = 0
initD = 5


beta = 1.33196952
beta1 = 4.63084450
beta2 = 0.40490382 
#alpha1=alpha1
k1 = 0.20000000
k2 = 0.30787840
deta1 = 0.00879924
deta2 = 0.00709197

gama1 = 0.05894342
gama2 = 0.25274607
alpha1=0.19767949
yita1=9.8492e-05
yita2=0.63955702
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=2, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0001)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
indian

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 1390000000
# S0 = 966000000
initS1 = 1
initE_0 = 60000
initE_V = 0
initI_0 = 14289
initI_V = 1
initR_0 = 19578
initR_V = 0
initR3 = 33431716
initR4 = 0
initD = 165

beta = 1.49522664
beta1 = 2.90190741
beta2 = 0.31279813
#alpha1=alpha1
k1 = 0.20000000
k2 = 0.30000074
deta1 = 0.11231476
deta2 = 0.06894592

gama1 = 0.01358997
gama2 = 0.14357084
alpha1=0.21504560
yita1=3.4779e-04
yita2=0.24684463
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
Austrilia

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 26000000
# S0 = 966000000
initS1 = 1
initE_0 = 6000
initE_V = 0
initI_0 = 2171
initI_V = 1
initR_0 = 16
initR_V = 0
initR3 = 110092
initR4 = 0
initD = 16

beta = 1.11125406
beta1 = 5.16976304
beta2 = 0.40922821
#alpha1=alpha1
k1 = 0.19942545
k2 = 0.33322637
deta1 =  0.01358088
deta2 = 2.5075e-04

gama1 = 0.06333933
gama2 =  0.24690072
alpha1=0.18117340
yita1=4.9971e-04
yita2=0.26038727
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b5d8e41d9ecb> in <module>
#      29 days =197
#      30
# ---> 31 params = Parameters()
#      32 params.add('beta', value=beta, min=0.2, max=1.5)
#      33 params.add('beta1', value=beta1, min=1.5, max=10)
#
# NameError: name 'Parameters' is not defined

# %%
Japan

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 125000000
# S0 = 966000000
initS1 = 1
initE_0 = 1000
initE_V = 0
initI_0 = 509
initI_V = 1
initR_0 = 993
initR_V = 0
initR3 = 1688299
initR4 = 0
initD = 14

beta = 1.42636888
beta1 = 5.14378248
beta2 = 0.60670298
#alpha1=alpha1
k1 = 0.17955752
k2 = 0.36997010
deta1 =  4.5482e-07
deta2 = 0.01413023

gama1 = 0.26993672
gama2 =  0.61038097
alpha1=0.29553581
yita1=3.6686e-04
yita2=0.35631656
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
Brazil

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 214000000
# S0 = 966000000
initS1 = 1
initE_0 = 10000
initE_V = 0
initI_0 = 5738
initI_V = 1
initR_0 = 10557
initR_V = 0
initR3 = 20794497
initR4 = 0
initD = 83

beta = 1.38975659
beta1 = 4.19863835
beta2 = 0.48004485
#alpha1=alpha1
k1 = 0.19999117
k2 = 0.30398496
deta1 =   0.04631163
deta2 = 1.5002e-07

gama1 = 0.08462090
gama2 = 0.23213318
alpha1=0.22285368
yita1= 4.9999e-04
yita2=0.83437201
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
South Korea1*

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 51780000
initI_C = 399591
# S0 = 966000000
initS1 = 1
initE_0 = 9672
initE_V = 0
initI_0 = 31466
initI_V = 1
initR_0 = 360891
initR_V = 0
initR3 = 0
initR4 = 0
initD = 3103

beta = 0.31213499
beta1 =0.87152799
beta2 = 0.31231543
k1 = 0.25000000
k2 = 0.37000000
deta1 = 0.07987868
deta2 = 0.00996049

gama1 =0.20895232
gama2 = 0.31982875 
alpha1=0.01126056
yita1=6.3899e-04
yita2= 8.1267e-03
days =230

params = Parameters()
params.add('beta', value=beta, min=0, max=5)
params.add('beta1', value=beta1, min=0, max=5)
params.add('beta2', value=beta2, min=0, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.08)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.03, max=0.22)
params.add('gama2', value=gama2, min=0.03, max=0.32)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.01)
params.add('yita2', value=yita2, min=0, max=0.001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-87853ff5d4f9> in <module>
#      29 days =197
#      30
# ---> 31 params = Parameters()
#      32 params.add('beta', value=beta, min=0.2, max=1.5)
#      33 params.add('beta1', value=beta1, min=1.5, max=10)
#
# NameError: name 'Parameters' is not defined

# %%
South Africa

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 60000000
# S0 = 966000000
initS1 = 1
initE_0 = 1000
initE_V = 0
initI_0 = 414
initI_V = 1
initR_0 = 515
initR_V = 0
initR3 = 2805186
initR4 = 0
initD = 25

beta = 1.41927097
beta1 = 3.50616463
beta2 = 0.65778611
#alpha1=alpha1
k1 =  0.19046731
k2 = 0.30004546
deta1 =   0.04181920
deta2 = 5.9237e-04

gama1 = 0.08598276
gama2 = 0.23471298
alpha1=0.23535180
yita1= 5.0000e-04
yita2=0.57586312
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
danmark

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 5900000
# S0 = 966000000
initS1 = 1
initE_0 = 10000
initE_V = 0
initI_0 = 3223
initI_V = 1
initR_0 = 1397
initR_V = 0
initR3 = 385492
initR4 = 0
initD = 7

beta = 1.16623545
beta1 = 4.46050079
beta2 = 0.49922419
#alpha1=alpha1
k1 =  0.20000000
k2 = 0.31242958
deta1 =  0.02599537
deta2 = 1.7627e-10

gama1 = 0.07363332
gama2 =  0.22181594
alpha1=0.19649624
yita1= 4.9972e-04
yita2=0.94264920
days =197

params = Parameters()
params.add('beta', value=beta, min=0.8, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=7)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=0.6)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
Turkey

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 85000000
# S0 = 966000000
initS1 = 1
initE_0 = 50000
initE_V = 0
initI_0 = 21665
initI_V = 1
initR_0 = 20007
initR_V = 0
initR3 = 8278610
initR4 = 0
initD = 213

beta = 1.11112503
beta1 = 4.66075321
beta2 = 0.45179634
#alpha1=alpha1
k1 =  0.20000000
k2 = 0.32801861
deta1 =   0.06580420
deta2 = 1.1809e-07

gama1 = 0.08358269
gama2 = 0.23159706
alpha1=0.18898233
yita1= 2.3740e-04
yita2=0.43030982
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=7)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.2)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=0.4)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
Cannada

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 38300000
# S0 = 966000000
initS1 = 1
initE_0 = 10000
initE_V = 0
initI_0 = 907
initI_V = 1
initR_0 = 373
initR_V = 0
initR3 = 1658945
initR4 = 0

beta = 1.48704210
beta1 = 3.60495054
beta2 = 0.47525107
#alpha1=alpha1
k1 =  0.21000000
k2 = 0.30016074
deta1 =   0.03097244
deta2 = 0.00559108

gama1 = 0.07980643
gama2 = 0.24858091
alpha1=0.23282510
yita1= 4.9556e-04
yita2=0.22168145
days =197

params = Parameters()
params.add('beta', value=beta, min=0.2, max=1.5)
params.add('beta1', value=beta1, min=1.5, max=10)
params.add('beta2', value=beta2, min=0, max=1)

params.add('k1', value=k1, min=0.15, max=0.21)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.3)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0, max=1)
params.add('gama2', value=gama2, min=0, max=1)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.0005)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
denmark2

# %%
*150000,3 points

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 5900000
# S0 = 966000000
initS1 = 1
initE_0 = 12892
initE_V = 0
initI_0 = 35063
initI_V = 1
initR_0 = 385492
initR_V = 0
initR3 = 0
initR4 = 0
initD = 2767

beta = 0.39302278
beta1 = 1.71305984
beta2 = 0.42155481
k1 = 0.25000000
k2 = 0.37000000
deta1 = 0.07766163
deta2 =  0.00238257

gama1 = 0.19970163
gama2 = 0.29999997
alpha1=0.04281056
yita1=6.0168e-08
yita2= 5.1625e-07
days =230

params = Parameters()
params.add('beta', value=beta, min=0, max=5)
params.add('beta1', value=beta1, min=0, max=5)
params.add('beta2', value=beta2, min=0, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.03, max=0.2)
params.add('gama2', value=gama2, min=0.03, max=0.3)
params.add('alpha1', value=alpha1, min=0, max=0.08)
params.add('yita1', value=yita1, min=0, max=0.1)
params.add('yita2', value=yita2, min=0, max=0.001)

# %%
South Korea2

# %%
150000*5

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 51780000
#initI_C = 399591
# S0 = 966000000
initS1 = 1
initE_0 = 9672
initE_V = 0
initI_0 = 31466
initI_V = 1
initR_0 = 360891
initR_V = 0
initR3 = 0
initR4 = 0
initD = 3103


beta = 0.29561551
beta1 =3.05232545
beta2 = 0.66988124
k1 = 0.25000000
k2 = 0.37000000
deta1 = 0.02044883
deta2 = 0.09999937

gama1 =0.05290986
gama2 = 0.39902057
alpha1=0.09987548
yita1=0.11380135 
yita2= 0.81503742
days =211

params = Parameters()
params.add('beta', value=beta, min=0, max=5)
params.add('beta1', value=beta1, min=0, max=7)
params.add('beta2', value=beta2, min=0, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0.05, max=0.4)
params.add('gama2', value=gama2, min=0.05, max=0.4)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.2)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
Malaysia

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 32800000

#initI_C = 2476268
# S0 = 966000000
initS1 = 1
initE_0 = 19916
initE_V = 0
initI_0 = 67969
initI_V = 1
initR_0 = 2374761
initR_V = 0
initR3 = 0
initR4 = 0
initD = 28912

beta = 0.32464179
beta1 = 0.94126115
beta2 =0.17775162
k1 = 0.25
k2 = 0.37
deta1 = 0.05140007
deta2 = 0.00999366

gama1 = 0.30796859
gama2 = 0.38985876
alpha1=0.00913774
yita1=0.04357119 
yita2= 0.55744079
days =178

params = Parameters()
params.add('beta', value=beta, min=0.1, max=5)
params.add('beta1', value=beta1, min=0.5, max=5)
params.add('beta2', value=beta2, min=0.1, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.05, max=0.4)
params.add('gama2', value=gama2, min=0.05, max=0.4)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.2)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 60000000
initI_C = 2953143
# S0 = 966000000
initS1 = 0
initE_0 = 1380
initE_V = 0
initI_0 = 22795
initI_V = 1
initR_0 = 2805186
initR_V = 0
initR3 = 0
initR4 = 0
initD = 88612

beta = 0.10810539
beta1 = 1.84854406
beta2 =  0.10172500
#alpha1=alpha1
k1 = 0.18608625
k2=  0.35478425
deta1 =0.03855231
deta2 = 0.00390263

gama1 = 0.36836614
gama2 = 0.38942183 
alpha1=0.02885239
yita1=2.8484e-11
yita2=0.37974675
days =211

params = Parameters()
params.add('beta', value=beta, min=0.1, max=5)
params.add('beta1', value=beta1, min=0.1, max=5)
params.add('beta2', value=beta2, min=0.1, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.05, max=0.4)
params.add('gama2', value=gama2, min=0.05, max=0.4)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.2)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
ice land

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 400000
initI_C =18044
# S0 = 966000000
initS1 = 1
initE_0 = 568
initE_V = 0
initI_0 = 1000
initI_V = 1
initR_0 = 18055
initR_V = 0
initR3 = 0
initR4 = 0
initD = 35

beta = 0.42605163
beta1 = 0.86071786
beta2 = 0.30808569
#alpha1=alpha1
k1 = 0.25000000
k2=  0.37000000
deta1 =0.02857055
deta2 =  0.00999999

gama1 =  0.22511183
gama2 = 0.33101105
alpha1=0.00851883
yita1=1.0126e-06
yita2= 8.9731e-13
days =140

params = Parameters()

params.add('beta', value=beta, min=0, max=5)
params.add('beta1', value=beta1, min=0, max=5)
params.add('beta2', value=beta2, min=0, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.05, max=0.4)
params.add('gama2', value=gama2, min=0.05, max=0.4)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.1)
params.add('yita2', value=yita2, min=0, max=0.1)

# %%
Bahrain

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 1700000
# S0 = 966000000
initS1 = 1
initE_0 = 1
initE_V = 0
initI_0 = 341
initI_V = 1
initR_0 =276355
initR_V = 0
initR3 = 0
initR4 = 0
initD = 1394

beta = 1.26329615
beta1 = 2.11158139
beta2 =  0.30679778 
#alpha1=alpha1
k1 = 0.25000000
k2=  0.37000000
deta1 =0.10000000
deta2 =  0.10000000

gama1 =  0.30000000
gama2 = 0.29997115
alpha1=0.04642130
yita1=0.03305947
yita2= 0.08749564
days =211

params = Parameters()
params = Parameters()
params.add('beta', value=beta, min=0.7, max=7)
params.add('beta1', value=beta1, min=1.5, max=7)
params.add('beta2', value=beta2, min=0.3, max=4)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.1)

params.add('gama1', value=gama1, min=0.05, max=0.3)
params.add('gama2', value=gama2, min=0.05, max=0.3)
params.add('alpha1', value=alpha1, min=0, max=0.3)
params.add('yita1', value=yita1, min=0, max=0.2)
params.add('yita2', value=yita2, min=0, max=1)

# %%
Spain

# %%
150000*4

# %%
initN = 47300000
# S0 = 966000000
initS1 = 1
initE_0 = 28000
initE_V = 0
initI_0 = 128771
initI_V = 1
initR_0 = 4914286
initR_V = 0
initR3 = 0
initR4 = 0
initD = 87995

beta =0.31938262
beta1 = 3.93977210
beta2 = 0.29105203
k1 = 0.25
k2 = 0.37
deta1 = 0.05902222
deta2 = 0.00999989

gama1 = 0.05000001
gama2 = 0.33731673
alpha1=0.07601319
yita1=2.2636e-08
yita2= 0.96286858
days =178
params = Parameters()
params.add('beta', value=beta, min=0, max=5)
params.add('beta1', value=beta1, min=0, max=5)
params.add('beta2', value=beta2, min=0, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.05, max=0.4)
params.add('gama2', value=gama2, min=0.05, max=0.4)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.2)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
South Africa 250000*2

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 60000000
initI_C = 2953143
# S0 = 966000000
initS1 = 0
initE_0 = 1380
initE_V = 0
initI_0 = 22795
initI_V = 1
initR_0 = 2805186
initR_V = 0
initR3 = 0
initR4 = 0
initD = 88612

beta = 0.10000874
beta1 =1.64663540
beta2 = 0.10561114
#alpha1=alpha1
k1 = 0.25000000
k2=  0.37000000
deta1 =0.09999974
deta2 = 0.00999999

gama1 = 0.09083375 
gama2 =  0.25000000
alpha1=0.03706841
yita1=1.1410e-05
yita2=0.20018837
days =160

params = Parameters()
params.add('beta', value=beta, min=0.1, max=5)
params.add('beta1', value=beta1, min=0.1, max=5)
params.add('beta2', value=beta2, min=0.1, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.1)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.01, max=0.2)
params.add('gama2', value=gama2, min=0.05, max=0.25)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.2)
params.add('yita2', value=yita2, min=0.2, max=1)

# %%
Africa BA.4/.5 25000*3 [126:]

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 60000000
initI_C = 3659698
# S0 = 966000000
initS1 = 2520000
initE_0 = 2773
initE_V = 55
initI_0 = 13489
initI_V = 23
initR_0 = 3627594
initR_V = 0
initR3 = 0
initR4 = 0
initD = 100147

beta = 0.29674282
beta1 =0.66307070 
beta2 =0.10208143
#alpha1=alpha1
k1 = 0.32093586
k2=     0.42847075
deta1 =0.001
deta2 =0.00999999

gama1 = 0.25000000
gama2 =   0.25000000
alpha1=0.01539293 
yita1=   0.01502007
yita2=  0.05193103
days =170

params = Parameters()
params.add('beta', value=beta, min=0, max=5)
params.add('beta1', value=beta1, min=0, max=5)
params.add('beta2', value=beta2, min=0, max=5)

params.add('k1', value=k1, min=0.3, max=0.37)
params.add('k2', value=k2, min=0.3, max=0.43)
params.add('deta1', value=deta1, min=0, max=0.01)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.05, max=0.25)
params.add('gama2', value=gama2, min=0.05, max=0.25)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.02)
params.add('yita2', value=yita2, min=0, max=0.01)

# %%
Denmark

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 5900000
# S0 = 966000000
initS1 = 1
initE_0 = 12892
initE_V = 0
initI_0 = 35063
initI_V = 1
initR_0 = 385492
initR_V = 0
#initR3 = 0
#initR4 = 0
initD = 2767

beta = 0.27235197
beta1 = 2.76360348
beta2 = 0.52144033
k1 = 0.25000000
k2 = 0.37000000
deta1 =0.00999984
deta2 = 0.00999864

gama1 = 0.12090686 
gama2 =0.34427598
alpha1=0.07467729 
yita1=2.6742e-11
yita2=2.1640e-05
days =178

params = Parameters()
params.add('beta', value=beta, min=0, max=5)
params.add('beta1', value=beta1, min=0.5, max=5)
params.add('beta2', value=beta2, min=0, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.01)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.03, max=0.3)
params.add('gama2', value=gama2, min=0.03, max=0.4)
params.add('alpha1', value=alpha1, min=0, max=0.08)
params.add('yita1', value=yita1, min=0, max=0.02)
params.add('yita2', value=yita2, min=0, max=0.01)

# %%
SPAIN

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 47300000
# S0 = 966000000
initS1 = 4650000
initE_0 = 28148
initE_V = 4
initI_0 = 128771
initI_V = 1
initR_0 = 4914286
initR_V = 0
#initR3 = 0
#initR4 = 0
initD = 87955

beta = 0.21120748
beta1 = 3.2
beta2 = 0.31689236
k1 = 0.25000000
k2 = 0.37000000
deta1 =0.04999992
deta2 =  0.01000000 

gama1 = 0.03000037 
gama2 =0.32608954
alpha1=0.06029824 
yita1=1.9701e-10
yita2=9.8882e-04
days =178

params = Parameters()
params.add('beta', value=beta, min=0.1, max=5)
params.add('beta1', value=beta1, min=0.5, max=5)
params.add('beta2', value=beta2, min=0.1, max=5)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.05)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.03, max=0.3)
params.add('gama2', value=gama2, min=0.05, max=0.4)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.001)
params.add('yita2', value=yita2, min=0, max=0.001)

# %%
# ref: https://www.medrxiv.org/content/10.1101/2020.04.01.20049825v1.full.pdf
initN = 60000000
initI_C = 2953143
# S0 = 966000000
initS1 = 1
initE_0 = 1380
initE_V = 0
initI_0 = 22795
initI_V = 1
initR_0 = 2805186
initR_V = 0
initR3 = 0
initR4 = 0
initD = 88612

beta = 0.10024031
beta1 =1.69765733
beta2 = 0.10000207
#alpha1=alpha1
k1 = 0.25000000
k2=  0.37000000
deta1 =0.07722340
deta2 = 0.00392667

gama1 = 0.11144296 
gama2 =  0.24975927
alpha1=0.03635349
yita1=9.8104e-04
yita2=2.5010e-08
days =130

params = Parameters()
params.add('beta', value=beta, min=0.1, max=1)
params.add('beta1', value=beta1, min=0.1, max=5)
params.add('beta2', value=beta2, min=0.1, max=1)

params.add('k1', value=k1, min=0.15, max=0.25)
params.add('k2', value=k2, min=0.3, max=0.37)
params.add('deta1', value=deta1, min=0, max=0.08)
params.add('deta2', value=deta2, min=0, max=0.01)

params.add('gama1', value=gama1, min=0.01, max=0.3)
params.add('gama2', value=gama2, min=0.05, max=0.3)
params.add('alpha1', value=alpha1, min=0, max=0.1)
params.add('yita1', value=yita1, min=0, max=0.001)
params.add('yita2', value=yita2, min=0, max=0.01)
